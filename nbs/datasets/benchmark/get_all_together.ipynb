# %%
import pandas as pd

from nlp4bia.datasets.benchmark.distemist import DistemistLoader, DistemistGazetteer
from nlp4bia.datasets.benchmark.symptemist import SymptemistLoader, SymptemistGazetteer
from nlp4bia.datasets.benchmark.medprocner import MedprocnerLoader, MedprocnerGazetteer

# %%
distemist = DistemistLoader()
symptemist = SymptemistLoader()
medprocner = MedprocnerLoader()

distemist_gaz = DistemistGazetteer()
symptemist_gaz = SymptemistGazetteer()
medprocner_gaz = MedprocnerGazetteer()
# Out:
# preprocessing data...
# preprocessing data...
# preprocessing data...
# preprocessing data...
# preprocessing data...
# preprocessing data...

# %%
distemist.df
# Out:
#                                   filenameid mention_class  \
# 0       es-S0210-56912007000900007-3#164#166    ENFERMEDAD
# 1       es-S0210-56912007000900007-3#362#376    ENFERMEDAD
# 2       es-S0210-56912007000900007-3#575#590    ENFERMEDAD
# 3       es-S0210-56912007000900007-3#715#733    ENFERMEDAD
# 4     es-S0210-56912007000900007-3#1402#1459    ENFERMEDAD
# ...                                      ...           ...
# 7729    es-S0212-16112011000300031-1#845#868    ENFERMEDAD
# 7730  es-S0212-16112011000300031-1#1034#1074    ENFERMEDAD
# 7731  es-S0212-16112011000300031-1#2321#2339    ENFERMEDAD
# 7732    es-S0212-16112011000300031-1#528#547    ENFERMEDAD
# 7733    es-S0212-16112011000300031-1#346#366    ENFERMEDAD
#
#                                                    span       code sem_rel  \
# 0                                                    DM   73211009   EXACT
# 1                                        deshidratación   34095006   EXACT
# 2                                       hiperamilasemia  275739007   EXACT
# 3                                    pancreatitis aguda  197456007   EXACT
# 4     formación polipoidea sésil situada junto al es...   88580009   EXACT
# ...                                                 ...        ...     ...
# 7729                            pinza aorto-mesentérica  235806008   EXACT
# 7730           trastorno del comportamiento alimentario   72366004   EXACT
# 7731                                 hipotonía gástrica   46218001   EXACT
# 7732                                patología digestiva  119292006   EXACT
# 7733                               patología infecciosa   40733004   EXACT
#
#      is_abbreviation is_composite needs_context extension_esp  \
# 0               None         None          None          None
# 1               None         None          None          None
# 2               None         None          None          None
# 3               None         None          None          None
# 4               None         None          None          None
# ...              ...          ...           ...           ...
# 7729            None         None          None          None
# 7730            None         None          None          None
# 7731            None         None          None          None
# 7732            None         None          None          None
# 7733            None         None          None          None
#
#                                                    text  split
# 0     Mujer de 74 años que ingresó en el hospital po...  train
# 1     Mujer de 74 años que ingresó en el hospital po...  train
# 2     Mujer de 74 años que ingresó en el hospital po...  train
# 3     Mujer de 74 años que ingresó en el hospital po...  train
# 4     Mujer de 74 años que ingresó en el hospital po...  train
# ...                                                 ...    ...
# 7729  Mujer de 31 años que ingresa en 2008 en el Ser...   test
# 7730  Mujer de 31 años que ingresa en 2008 en el Ser...   test
# 7731  Mujer de 31 años que ingresa en 2008 en el Ser...   test
# 7732  Mujer de 31 años que ingresa en 2008 en el Ser...   test
# 7733  Mujer de 31 años que ingresa en 2008 en el Ser...   test
#
# [7734 rows x 11 columns]

# %%
total_data = pd.concat([distemist.df, symptemist.df, medprocner.df], ignore_index=True)

# %%
total_gaz = pd.concat([distemist_gaz.df, symptemist_gaz.df, medprocner_gaz.df], ignore_index=True)

# %%
total_data.shape
# Out:
# (28223, 11)

# %%
total_gaz.shape
# Out:
# (546771, 5)

# %%
total_data[total_data["split"] == "train"].shape
# Out:
# (18973, 11)

# %%
total_data[total_data["split"] == "test"].shape
# Out:
# (9250, 11)

# %%
total_data
# Out:
#                                    filenameid  mention_class  \
# 0        es-S0210-56912007000900007-3#164#166     ENFERMEDAD
# 1        es-S0210-56912007000900007-3#362#376     ENFERMEDAD
# 2        es-S0210-56912007000900007-3#575#590     ENFERMEDAD
# 3        es-S0210-56912007000900007-3#715#733     ENFERMEDAD
# 4      es-S0210-56912007000900007-3#1402#1459     ENFERMEDAD
# ...                                       ...            ...
# 28218  es-S2340-98942015000100005-1#1732#1795  PROCEDIMIENTO
# 28219    es-S2340-98942015000100005-1#231#284  PROCEDIMIENTO
# 28220    es-S2340-98942015000100005-1#465#468  PROCEDIMIENTO
# 28221    es-S2340-98942015000100005-1#533#569  PROCEDIMIENTO
# 28222    es-S2340-98942015000100005-1#574#620  PROCEDIMIENTO
#
#                                                     span       code sem_rel  \
# 0                                                     DM   73211009   EXACT
# 1                                         deshidratación   34095006   EXACT
# 2                                        hiperamilasemia  275739007   EXACT
# 3                                     pancreatitis aguda  197456007   EXACT
# 4      formación polipoidea sésil situada junto al es...   88580009   EXACT
# ...                                                  ...        ...     ...
# 28218  quimioterapia con trabectedina y adriamicina l...  367336001  NARROW
# 28219  quimioterapia adyuvante con carboplatino y pac...  367336001  NARROW
# 28220                                                TAC   77477000   EXACT
# 28221               resección anterior de recto superior  172341002   EXACT
# 28222     biopsia intraoperatoria de una lesión hepática  274355008   EXACT
#
#       is_abbreviation is_composite needs_context extension_esp  \
# 0                None         None          None          None
# 1                None         None          None          None
# 2                None         None          None          None
# 3                None         None          None          None
# 4                None         None          None          None
# ...               ...          ...           ...           ...
# 28218            None        False         False          None
# 28219            None        False         False          None
# 28220            None        False         False          None
# 28221            None        False         False          None
# 28222            None        False         False          None
#
#                                                     text  split
# 0      Mujer de 74 años que ingresó en el hospital po...  train
# 1      Mujer de 74 años que ingresó en el hospital po...  train
# 2      Mujer de 74 años que ingresó en el hospital po...  train
# 3      Mujer de 74 años que ingresó en el hospital po...  train
# 4      Mujer de 74 años que ingresó en el hospital po...  train
# ...                                                  ...    ...
# 28218  Presentamos el caso de una paciente de 62 años...   test
# 28219  Presentamos el caso de una paciente de 62 años...   test
# 28220  Presentamos el caso de una paciente de 62 años...   test
# 28221  Presentamos el caso de una paciente de 62 años...   test
# 28222  Presentamos el caso de una paciente de 62 años...   test
#
# [28223 rows x 11 columns]
